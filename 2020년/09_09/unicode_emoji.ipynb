# %%
import json
with open("1.json", "r") as fp:
        temp_json =json.load(fp)

# %%
import pandas as pd
content_ls = pd.DataFrame(temp_json)['content']

# %%
import emoji

# %%
content_ls[0]
# Out:
# '#3747다이어트\n#과일모닝\n🥝🍠🍐 과일은 사랑사랑🙆\n상큼하게 시작하는 오늘 하루\n주말이라 남편이랑 데이트하는날이지만 최대한 클린클린하게!\n.\n.\n.\n오늘도 화이팅!\n오후에 콩필라테스랑\n스트레칭할예정💗\n.\n.\n.\n.\n.\n.\n.\n.\n#다이어트 #다이어터 #diet #dieter #식단인증 #식단기록 #workout #다이어터맞팔 #다이어터소통 #다이어터환영 #홈트하는여자 #관리하는여자 #체중감량 #체중조절 #살빼기 #탄단지 #온더테이블 #dietfood #직장인다이어터 #주부다이어터 #요리하는여자 #홈쿡 #다이어트스타그램 #다이어트계정'

# %%
dir(emoji)
# Out:
# ['EMOJI_ALIAS_UNICODE',
#  'EMOJI_UNICODE',
#  'UNICODE_EMOJI',
#  'UNICODE_EMOJI_ALIAS',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__email__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__source__',
#  '__spec__',
#  '__version__',
#  'core',
#  'demojize',
#  'emoji_count',
#  'emoji_lis',
#  'emojize',
#  'get_emoji_regexp',
#  'unicode_codes']

# %%
import emoji
emoji.UNICODE_EMOJI
# Out:
# {'🥇': ':1st_place_medal:',
#  '🥈': ':2nd_place_medal:',
#  '🥉': ':3rd_place_medal:',
#  '🆎': ':AB_button_(blood_type):',
#  '🏧': ':ATM_sign:',
#  '🅰': ':A_button_(blood_type):',
#  '🅰️': ':A_button_(blood_type)_selector:',
#  '🇦🇫': ':Afghanistan:',
#  '🇦🇽': ':Aland_Islands:',
#  '🇦🇱': ':Albania:',
#  '🇩🇿': ':Algeria:',
#  '🇦🇸': ':American_Samoa:',
#  '🇦🇩': ':Andorra:',
#  '🇦🇴': ':Angola:',
#  '🇦🇮': ':Anguilla:',
#  '🇦🇶': ':Antarctica:',
#  '🇦🇬': ':Antigua_&_Barbuda:',
#  '♒': ':Aquarius:',
#  '🇦🇷': ':Argentina:',
#  '♈': ':Aries:',
#  '🇦🇲': ':Armenia:',
#  '🇦🇼': ':Aruba:',
#  '🇦🇨': ':Ascension_Island:',
#  '🇦🇺': ':Australia:',
#  '🇦🇹': ':Austria:',
#  '🇦🇿': ':Azerbaijan:',
#  '🔙': ':BACK_arrow:',
#  '🅱': ':B_button_(blood_type):',
#  '🅱️': ':B_button_(blood_type)_selector:',
#  '🇧🇸': ':Bahamas:',
#  '🇧🇭': ':Bahrain:',
#  '🇧🇩': ':Bangladesh:',
#  '🇧🇧': ':Barbados:',
#  '🇧🇾': ':Belarus:',
#  '🇧🇪': ':Belgium:',
#  '🇧🇿': ':Belize:',
#  '🇧🇯': ':Benin:',
#  '🇧🇲': ':Bermuda:',
# ...

# %%
if '😆' in emoji.UNICODE_EMOJI :
    print('일반 문자열에서 이모지 추출 가능')
else :
    print("유니코드로 변환 필요")
# Out:
# 일반 문자열에서 이모지 추출 가능

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# ^C

# %%
from pykospacing import spacing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-64-6c5cf9e59f47> in <module>
# ----> 1 from pykospacing import spacing
#
# ModuleNotFoundError: No module named 'pykospacing'

# %%
from konlpy.tag import Okt
